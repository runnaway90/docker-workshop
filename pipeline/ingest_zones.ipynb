# %%
# !wget https://d37ci6vzurychx.cloudfront.net/misc/taxi_zone_lookup.csv
# Out:
# --2026-05-04 08:46:33--  https://d37ci6vzurychx.cloudfront.net/misc/taxi_zone_lookup.csv
# Resolving d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)... 18.239.38.147, 18.239.38.181, 18.239.38.163, ...
# Connecting to d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)|18.239.38.147|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2026-05-04 08:46:33 ERROR 403: Forbidden.

# %%
import pandas as pd

# %%
df_zones = pd.read_csv('taxi_zone_lookup.csv')

# %%
df_zones.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
from sqlalchemy import create_engine

# %%
# Connect to PostgreSQL
engine = create_engine('postgresql+psycopg://root:root@localhost:5432/ny_taxi')

# Write to database
df_zones.to_sql(
    name='zones',  # table name
    con=engine,
    if_exists='replace'  # or 'append' to add to existing table
)
# Out:
# -1
